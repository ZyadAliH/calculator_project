# %% [markdown]
# Welcome to calculator

# %%
print("welcome to calculator project")

num1 = int(input("please enter the first number: "))
operator = input("please enter the operator:")
num2 = int(input("please enter the secound number:"))

def worng(operator):
    if operator != "+" and operator != "-" and operator != "*" and operator != "/" and operator != "%":
        print("worng please enter the operator try again")

def sum(num1 , operator , num2 ):
    if operator == "+":
        print(num1 + num2)

def subtract(num1, operator ,num2 ):
    if operator == "-":
        print(num1 - num2)

def Multiply(num1, operator ,num2 ):
    if operator == "*":
        print(num1 * num2)
    
def division(num1 , operator , num2):
    if operator == "/":
        print(num1 / num2)
    
def division_2(num1 , operator , num2 ):
    if operator == "%":
        print(num1 % num2)
    
worng (operator)
sum(num1 , operator , num2 )
subtract(num1 , operator , num2)
Multiply(num1 , operator ,num2 )
division(num1 , operator , num2 )
division_2(num1 , operator , num2)
# Out:
# welcome to calculator project
